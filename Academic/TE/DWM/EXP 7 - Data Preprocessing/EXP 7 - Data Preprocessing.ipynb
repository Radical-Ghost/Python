# %%
import pandas as pd
import numpy as np
import  matplotlib.pyplot as plt
import seaborn as sns

# %%
df =  pd.read_csv('zomato.csv', encoding='latin-1') # Read the data
df.sample(5) # Display 5 random rows
# Out:
#       Restaurant ID          Restaurant Name  Country Code       City  \
# 8512       18265705    M.P. Chole Tikki Wala             1      Noida
# 7782         310876        Fatafat Fast Food             1  New Delhi
# 2526        3300138                Checker's             1     Nagpur
# 6025         302155  Madan Cafe & Restaurant             1  New Delhi
# 6172         312990           Chawla Kitchen             1  New Delhi
#
#                                                 Address            Locality  \
# 8512                          Block D, Sector 27, Noida           Sector 27
# 7782  A-60, Sarpanch Chowk, New Ashok Nagar, Near, V...  Vasundhara Enclave
# 2526         23 to 25, VCA Complex, Civil Lines, Nagpur         Civil Lines
# 6025            1601, Main Bazaar, Paharganj, New Delhi           Paharganj
# 6172  G-29, Vardhaman Plaza, Near Bank Of India Bank...       Paschim Vihar
#
#                    Locality Verbose  Longitude   Latitude  \
# ...

# %%
df.info() # Display the information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe() # Display the statistical summary of the dataset
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df.shape # Display the shape of the dataset
# Out:
# (9551, 21)

# %%
df.isnull().sum() # Display the number of missing values in the dataset
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
sns.heatmap(df.isnull(), cbar=False) # Display the missing values in the dataset
#due to it being too large, we can't see the missing values in the dataset
# Out:
# <Axes: >

# %%
#missing values in the dataset
missing = [i for i in df.columns if df[i].isnull().sum() > 0]
print(missing)
# Out:
# ['Cuisines']

# %%
print(df.duplicated()) # Display the duplicated values in the dataset
print("\nDropped Duplicates: ", df.drop_duplicates(inplace=True)) # Drop the duplicated values in the dataset
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9546    False
# 9547    False
# 9548    False
# 9549    False
# 9550    False
# Length: 9551, dtype: bool
#
# Dropped Duplicates:  None

# %%
df_numbers_only = df.select_dtypes(include=[np.number]) # Select only the numerical columns
df_numbers_only.sample(5)
# Out:
#       Restaurant ID  Country Code   Longitude   Latitude  \
# 5405       18489825             1   77.144937  28.494131
# 8825         304487             1   77.353187  28.610070
# 6227       18208914             1   77.306191  28.631137
# 7480           1900             1   77.195872  28.596312
# 321        16611498            14  151.558475 -32.728097
#
#       Average Cost for two  Price range  Aggregate rating  Votes
# 5405                   200            1               0.0      0
# 8825                   150            1               0.0      0
# 6227                   500            2               3.4     27
# 7480                  3700            4               3.6    100
# 321                     20            2               3.6     18

# %%
df_numbers_only.corr() # Display the correlation between the numerical columns
# Out:
#                       Restaurant ID  Country Code  Longitude  Latitude  \
# Restaurant ID              1.000000      0.148471  -0.226081 -0.052081
# Country Code               0.148471      1.000000  -0.698299  0.019792
# Longitude                 -0.226081     -0.698299   1.000000  0.043207
# Latitude                  -0.052081      0.019792   0.043207  1.000000
# Average Cost for two      -0.001693      0.043225   0.045891 -0.111088
# Price range               -0.134540      0.243327  -0.078939 -0.166688
# Aggregate rating          -0.326212      0.282189  -0.116818  0.000516
# Votes                     -0.147023      0.154530  -0.085101 -0.022962
#
#                       Average Cost for two  Price range  Aggregate rating  \
# Restaurant ID                    -0.001693    -0.134540         -0.326212
# Country Code                      0.043225     0.243327          0.282189
# Longitude                         0.045891    -0.078939         -0.116818
# ...

# %%
sns.heatmap(df_numbers_only.corr(), annot=True) # Display the correlation between the numerical columns
# Out:
# <Axes: >

# %%
Country = pd.read_excel("Country-Code.xlsx")  # Read the country code
Country.sample(5)
# Out:
#     Country Code       Country
# 12           214           UAE
# 10           191     Sri Lanka
# 1             14     Australia
# 9            189  South Africa
# 8            184     Singapore

# %%
Country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  15 non-null     int64
#  1   Country       15 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 372.0+ bytes

# %%
comb_pd = pd.merge(df, Country, left_on='Country Code', right_on='Country Code') # Merge the two datasets
comb_pd.sample(5)
# Out:
#       Restaurant ID               Restaurant Name  Country Code       City  \
# 995        18241538  Bikaneri Sweets & Restaurant             1  Faridabad
# 9514        5800176              Ministry of Crab           191    Colombo
# 8030       18429375            Sufiyan Restaurant             1  New Delhi
# 4402       18414477                        Faasos             1  New Delhi
# 5288       18208900                  Cafe Tandoor             1  New Delhi
#
#                                                 Address  \
# 995   Ankhir Road, Near Union Bank, Opposite Sector ...
# 9514       Old Colombo Dutch Hospital, Fort, Colombo 01
# 8030           57/12, Main Road, Zakir Nagar, New Delhi
# 4402  Shop N-9, Ground Floor, Opposite ICICI Bank, N...
# 5288  G-6, Kanishka Complex, Mayur Vihar Phase 1, Ne...
#
#                       Locality                   Locality Verbose  Longitude  \
# 995                  Sector 21               Sector 21, Faridabad   0.000000
# ...

# %%
print(comb_pd.Country.value_counts()) # Display the number of restaurants in each country
country_names = comb_pd.Country.value_counts().index 
country_values = comb_pd.Country.value_counts().values
# Out:
# Country
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# South Africa        60
# UAE                 60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Qatar               20
# Singapore           20
# Sri Lanka           20
# Canada               4
# Name: count, dtype: int64

# %%
plt.pie(country_values, labels=country_names, autopct='%1.1f%%') # Display the number of restaurants in each country
plt.show()

# %%
plt.pie(country_values[:3], labels=country_names[:3]) # Display the number of restaurants in the top 5 countries
plt.show()

# %% [markdown]
# <h3>Observations</h3>
#
# <ul>
#     <li> Zomato's Maximum transactions are from India</li>
#     <li> After India Zomato is moderately present in United States and United Kingdom</li>
#     <li> Zomato is bareley present in other countries</li>
# </ul>
